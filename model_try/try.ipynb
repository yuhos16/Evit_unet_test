# %%
import torch
from eff_unet import Eff_Unet

# 构建模型（假设模型定义在 unet.py 中）
net = Eff_Unet(
    layers=[5, 5, 15, 10],
    embed_dims=[40, 80, 192, 384],
    downsamples=[True, True, True, True],
    vit_num=6,
    drop_path_rate=0.1,
    num_classes=8
).cuda()

# 如果有预训练权重，加载预训练权重
# checkpoint = torch.load("path_to_checkpoint.pth")
# net.load_state_dict(checkpoint['model'] if 'model' in checkpoint else checkpoint)

net.eval()  # 导出前一定要将模型置为 eval 模式

# 创建一个 dummy input，形状为 (1, 3, 256, 256)
dummy_input = torch.randn(1, 3, 224, 224).cuda()

# 导出为 ONNX 模型文件
onnx_file = "eff_unet.onnx"
torch.onnx.export(net,                  # 要导出的模型
                  dummy_input,          # 模型的输入（或者输入元组）
                  onnx_file,            # 导出的 ONNX 文件名
                  export_params=True,   # 是否导出模型参数
                  opset_version=11,     # ONNX 版本（推荐 11 或更高）
                  do_constant_folding=True,  # 是否进行常量折叠优化
                  input_names=["input"],     # 输入节点名称
                  output_names=["output"],   # 输出节点名称
                  dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}})  # 动态 batch 维度

print(f"ONNX model exported to {onnx_file}")
# Out:
# ---------------------------------------------------------------------------
# SymbolicValueError                        Traceback (most recent call last)
# Cell In[4], line 25
#      23 # 导出为 ONNX 模型文件
#      24 onnx_file = "eff_unet.onnx"
# ---> 25 torch.onnx.export(net,                  # 要导出的模型
#      26                   dummy_input,          # 模型的输入（或者输入元组）
#      27                   onnx_file,            # 导出的 ONNX 文件名
#      28                   export_params=True,   # 是否导出模型参数
#      29                   opset_version=11,     # ONNX 版本（推荐 11 或更高）
#      30                   do_constant_folding=True,  # 是否进行常量折叠优化
#      31                   input_names=["input"],     # 输入节点名称
#      32                   output_names=["output"],   # 输出节点名称
#      33                   dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}})  # 动态 batch 维度
#      35 print(f"ONNX model exported to {onnx_file}")
#
# ...
